# %% [markdown]
# # __Exercise 2 - Create a markdown cell with the title of the notebook. (1 pt)__
# Tool for data science and Ecosystem

# %% [markdown]
# __Exercise 1: Create a Jupyter Notebook__
#
# Create a new Jupyter notebook called DataScienceEcosystem.ipynb

# %% [markdown]
# __Exercise 3 - Create a markdown cell for an introduction. (1 pt)__
#
# Introduction: This course introduces open-source data management tools, open-source data integration and transformation tools, its data visualization tools, model tools for building, deployment, monitoring, and assessment, and tools for code and data asset management. Along with making Comparsion and contrasts different open-source tools, and Describe the relevant features of open-source tools. It also describe how commercial cloud tools support data science tasks and explain how integration provides the ability to use the same tools for multiple tasks. Its mainly Identify the criteria for determining the language to learn and
# List the roles involved in data science. It provide introduction to Python,R, sql and data science languages and then listed the libraries for Data Science and much more

# %% [markdown]
# __Exercise 4 - Create a markdown cell to list data science languages. (3 pts)__
# list of data science langauges are
# 1. Python
# 2. R,
# 3. SQL,
# 4. JavaScript
# 5. PHP
# 6. Go
# 7. Ruby
# 8. Visual Basic
# 9. Java
# 10. Scala
# 11. C++
# 12. JavaScript
# 13. Julia

# %% [markdown]
# __Exercise 5 - Create a markdown cell to list data science libraries. (3 pts)__
#
# list of data science librarties are
# 1. Pandas
# 2. Numpy
# 3. Matplotlib
# 4. Keras
# 5. TensorFlow
# 6. PyTorch
# 7. Scikit-learn.

# %% [markdown]
# __Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)__
#
# |Data Science tools      |                   Description                                   |
# | -----------------------|  -------------------------------------------------------------- |
# |Data management tools   | MySQL, PostgreSQL, MongoDB, Apache CouchDB, Apache Cassandra    |
# |Data integration        | Apache AirFlow, KubeFlow, Apache Kafka, Apache                  |
# |Data Visualization tools| Pixie Dust, Hue, Kibana, and Apache Superset.                   |

# %% [markdown]
# ### __Exercise 7 - Create a markdown cell introducing arithmetic expression examples. (1 pt)__
#
#
# Below are a few examples of evaluating arithmetic expressions in Python

# %%
#Exercise 8 - Create a code cell to multiply and add numbers

(3*4)+5  #This a simple arithmetic expression to mutiply then add integers
# Out:
# 17

# %%
#Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)

min = 200
print("Hour : Minute :--> ", min//60, " : ", min % 60) #his will convert 200 minutes to hours by diving by 60
# Out:
# Hour : Minute :-->  3  :  20

# %% [markdown]
# __Exercise 10 -Insert a markdown cell to list Objectives. (3 pts)__
#
# __Objective__
#
# 2. List the tools of data science
# 3. List the libraries of data science
# 5. list the data science languages

# %% [markdown]
#  __Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)__
#
#  ## author: IBM watsonx
# Khadeeja Tariq
